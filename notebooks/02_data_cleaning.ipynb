# %%
import pandas as pd
import numpy as np

# %%
users = pd.read_csv("data/users.csv")
videos = pd.read_csv("data/videos.csv")
events = pd.read_csv("data/events.csv")

# %%
users.info()
videos.info()
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             10000 non-null  object
#  1   signup_date         10000 non-null  object
#  2   country             10000 non-null  object
#  3   device              10000 non-null  object
#  4   age_group           10000 non-null  object
#  5   gender              10000 non-null  object
#  6   acquisition_source  10000 non-null  object
#  7   premium_user        10000 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 625.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             5000 non-null   object
#  1   creator_id           5000 non-null   object
#  2   category             5000 non-null   object
#  3   language             5000 non-null   object
#  4   upload_date          5000 non-null   object
#  5   duration_sec         5000 non-null   int64
#  6   has_hashtags         5000 non-null   int64
#  7   is_verified_creator  5000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 312.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688732 entries, 0 to 688731
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   event_id         688732 non-null  object
#  1   user_id          688732 non-null  object
#  2   video_id         688732 non-null  object
#  3   event_type       688732 non-null  object
#  4   timestamp        688732 non-null  object
#  5   watch_time_sec   688732 non-null  object
#  6   watch_completed  688732 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 36.8+ MB

# %%
users.isnull().sum()
videos.isnull().sum()
events.isnull().sum()
# Out:
# event_id           0
# user_id            0
# video_id           0
# event_type         0
# timestamp          0
# watch_time_sec     0
# watch_completed    0
# dtype: int64

# %%
users.describe(include='all')
videos.describe(include='all')
events.describe(include='all')
# Out:
#        event_id user_id video_id event_type            timestamp  \
# count    688732  688732   688732     688732               688732
# unique   688732   10000     5000          5               683228
# top     E688732  U02672   V01009       View  2026-04-27 08:28:27
# freq          1     127      192     499207                    3
# mean        NaN     NaN      NaN        NaN                  NaN
# std         NaN     NaN      NaN        NaN                  NaN
# min         NaN     NaN      NaN        NaN                  NaN
# 25%         NaN     NaN      NaN        NaN                  NaN
# 50%         NaN     NaN      NaN        NaN                  NaN
# 75%         NaN     NaN      NaN        NaN                  NaN
# max         NaN     NaN      NaN        NaN                  NaN
#
#        watch_time_sec  watch_completed
# count          688732    688732.000000
# unique            181              NaN
# top                \N              NaN
# freq           189525              NaN
# mean              NaN         0.079015
# std               NaN         0.269762
# min               NaN         0.000000
# 25%               NaN         0.000000
# 50%               NaN         0.000000
# 75%               NaN         0.000000
# max               NaN         1.000000
